# %%
import pandas as pd

# %%
data1 = pd.read_csv("JC-201907-citibike-tripdata.csv") 
data2 = pd.read_csv("JC-201908-citibike-tripdata.csv") 
data3 = pd.read_csv("JC-201909-citibike-tripdata.csv")

# %%
data1.head()
#data1.info()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
data2.head()
#data2.info()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
data3.head()
#data3.info()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
dfs =[data1,data2,data3]

# %%
data_df = pd.concat(dfs)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141168 entries, 0 to 48710
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             141168 non-null  int64
#  1   starttime                141168 non-null  object
#  2   stoptime                 141168 non-null  object
#  3   start station id         141168 non-null  int64
#  4   start station name       141168 non-null  object
#  5   start station latitude   141168 non-null  float64
#  6   start station longitude  141168 non-null  float64
#  7   end station id           141168 non-null  int64
#  8   end station name         141168 non-null  object
#  9   end station latitude     141168 non-null  float64
#  10  end station longitude    141168 non-null  float64
#  11  bikeid                   141168 non-null  int64
#  12  usertype                 141168 non-null  object
# ...

# %%
data_df.to_csv('bike_data.csv')

# %%
data = pd.read_csv("bike_data.csv")

# %%
data.head(-100)
#data.info()
# Out:
#         Unnamed: 0  tripduration                 starttime  \
# 0                0          1793  2019-07-01 00:00:36.6150
# 1                1           434  2019-07-01 00:02:54.6150
# 2                2           251  2019-07-01 00:03:27.5670
# 3                3           636  2019-07-01 00:03:56.1690
# 4                4           623  2019-07-01 00:04:16.2060
# ...            ...           ...                       ...
# 141596       49139           107  2019-09-30 20:20:06.3400
# 141597       49140           396  2019-09-30 20:21:38.4240
# 141598       49141           765  2019-09-30 20:23:26.2080
# 141599       49142           258  2019-09-30 20:24:02.5780
# 141600       49143           314  2019-09-30 20:28:18.7830
#
#                         stoptime  start station id  \
# 0       2019-07-01 00:30:30.5940              3186
# 1       2019-07-01 00:10:09.0370              3206
# 2       2019-07-01 00:07:38.6080              3186
# ...

# %%
data['start station id'].value_counts()
# Out:
# 3186    15579
# 3203     8768
# 3639     6653
# 3202     6159
# 3195     5884
# 3792     5472
# 3276     5344
# 3199     4324
# 3638     3882
# 3211     3880
# 3187     3755
# 3267     3660
# 3185     3422
# 3269     3185
# 3184     3183
# 3192     3157
# 3272     3046
# 3275     3042
# 3270     3041
# 3213     2966
# 3209     2746
# 3278     2726
# 3205     2576
# 3194     2517
# 3273     2476
# 3214     2270
# 3640     2240
# 3681     2194
# 3279     2154
# 3207     1485
# 3210     1435
# 3483     1415
# 3225     1343
# 3193     1213
# 3268     1192
# 3481     1187
# 3678     1159
# 3280     1105
# 3198     1034
# 3679      995
# 3220      928
# 3206      919
# 3791      871
# 3277      815
# 3677      788
# 3196      784
# 3281      740
# 3212      715
# 3201      455
# 3191      428
# 3694      386
# 3426        8
# Name: start station id, dtype: int64

# %%
data['end station id'].value_counts()
# Out:
# 3186    19498
# 3203     7875
# 3639     6749
# 3202     6545
# 3792     6469
#         ...
# 484         1
# 285         1
# 3674        1
# 303         1
# 464         1
# Name: end station id, Length: 83, dtype: int64
